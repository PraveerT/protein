# %%
# !CUDA_VISIBLE_DEVICES=0 python main.py --finetune_model --config cfgs/protein.yaml --exp_name Protein
# Out:
# training from scratch
# Create experiment path successfully at ./experiments/protein/cfgs/Protein/20250829-171711
# Create TFBoard path successfully at ./experiments/protein/cfgs/TFBoard/Protein/20250829-171711
# 2025-08-29 17:17:11,493 - protein - INFO - Copy the Config file from cfgs/protein.yaml to ./experiments/protein/cfgs/Protein/20250829-171711/config.yaml
# 2025-08-29 17:17:11,494 - protein - INFO - args.config : cfgs/protein.yaml
# 2025-08-29 17:17:11,495 - protein - INFO - args.launcher : none
# 2025-08-29 17:17:11,495 - protein - INFO - args.local_rank : 0
# 2025-08-29 17:17:11,495 - protein - INFO - args.num_workers : 4
# 2025-08-29 17:17:11,495 - protein - INFO - args.seed : 0
# 2025-08-29 17:17:11,496 - protein - INFO - args.deterministic : False
# 2025-08-29 17:17:11,496 - protein - INFO - args.sync_bn : False
# 2025-08-29 17:17:11,496 - protein - INFO - args.exp_name : Protein
# 2025-08-29 17:17:11,496 - protein - INFO - args.loss : cd1
# ...

# %%
# !CUDA_VISIBLE_DEVICES=0 python main.py --finetune_model --config cfgs/protein.yaml --exp_name Protein
# Out:
# training from scratch
# Create experiment path successfully at ./experiments/protein/cfgs/Protein/20250830-044513
# Create TFBoard path successfully at ./experiments/protein/cfgs/TFBoard/Protein/20250830-044513
# 2025-08-30 04:45:13,729 - protein - INFO - Copy the Config file from cfgs/protein.yaml to ./experiments/protein/cfgs/Protein/20250830-044513/config.yaml
# 2025-08-30 04:45:13,731 - protein - INFO - args.config : cfgs/protein.yaml
# 2025-08-30 04:45:13,732 - protein - INFO - args.launcher : none
# 2025-08-30 04:45:13,732 - protein - INFO - args.local_rank : 0
# 2025-08-30 04:45:13,733 - protein - INFO - args.num_workers : 4
# 2025-08-30 04:45:13,734 - protein - INFO - args.seed : 0
# 2025-08-30 04:45:13,735 - protein - INFO - args.deterministic : False
# 2025-08-30 04:45:13,735 - protein - INFO - args.sync_bn : False
# 2025-08-30 04:45:13,737 - protein - INFO - args.exp_name : Protein
# 2025-08-30 04:45:13,738 - protein - INFO - args.loss : cd1
# ...
