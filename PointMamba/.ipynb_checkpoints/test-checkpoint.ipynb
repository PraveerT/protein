# %%
# !CUDA_VISIBLE_DEVICES=0 python main.py --finetune_model --config cfgs/protein.yaml --exp_name Protein
# Out:
# training from scratch
# Create experiment path successfully at ./experiments/protein/cfgs/Protein/20250825-131903
# Create TFBoard path successfully at ./experiments/protein/cfgs/TFBoard/Protein/20250825-131903
# 2025-08-25 13:19:03,210 - protein - INFO - Copy the Config file from cfgs/protein.yaml to ./experiments/protein/cfgs/Protein/20250825-131903/config.yaml
# 2025-08-25 13:19:03,217 - protein - INFO - args.config : cfgs/protein.yaml
# 2025-08-25 13:19:03,220 - protein - INFO - args.launcher : none
# 2025-08-25 13:19:03,224 - protein - INFO - args.local_rank : 0
# 2025-08-25 13:19:03,226 - protein - INFO - args.num_workers : 8
# 2025-08-25 13:19:03,228 - protein - INFO - args.seed : 0
# 2025-08-25 13:19:03,231 - protein - INFO - args.deterministic : False
# 2025-08-25 13:19:03,232 - protein - INFO - args.sync_bn : False
# 2025-08-25 13:19:03,233 - protein - INFO - args.exp_name : Protein
# 2025-08-25 13:19:03,235 - protein - INFO - args.loss : cd1
# ...

# %%
# !CUDA_VISIBLE_DEVICES=0 python main.py --finetune_model --config cfgs/finetune_scan_objbg.yaml --exp_name Protein
# Out:
# training from scratch
# Create experiment path successfully at ./experiments/finetune_scan_objbg/cfgs/Protein/20250825-131559
# Create TFBoard path successfully at ./experiments/finetune_scan_objbg/cfgs/TFBoard/Protein/20250825-131559
# 2025-08-25 13:15:59,454 - finetune_scan_objbg - INFO - Copy the Config file from cfgs/finetune_scan_objbg.yaml to ./experiments/finetune_scan_objbg/cfgs/Protein/20250825-131559/config.yaml
# 2025-08-25 13:15:59,454 - finetune_scan_objbg - INFO - args.config : cfgs/finetune_scan_objbg.yaml
# 2025-08-25 13:15:59,454 - finetune_scan_objbg - INFO - args.launcher : none
# 2025-08-25 13:15:59,454 - finetune_scan_objbg - INFO - args.local_rank : 0
# 2025-08-25 13:15:59,455 - finetune_scan_objbg - INFO - args.num_workers : 8
# 2025-08-25 13:15:59,455 - finetune_scan_objbg - INFO - args.seed : 0
# 2025-08-25 13:15:59,455 - finetune_scan_objbg - INFO - args.deterministic : False
# 2025-08-25 13:15:59,455 - finetune_scan_objbg - INFO - args.sync_bn : False
# ...
